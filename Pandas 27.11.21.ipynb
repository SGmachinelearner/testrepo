# %%
import pandas as pd

# %%
df1 =pd.read_csv('F:\\Sachin\\IT Study\\Python\\Pandas\\Fortune_10.csv')
df1
# Out:
#                                                                                                         ID\tName\tIndustry\tInception\tRevenue\tExpenses\tProfit\tGrowth
# 1\tLamtone\tIT Services\t2009\t"$11              757 018 "\t"6              482                                                 465 Dollars"\t5274553\t30%
# 2\tStripfind\tFinancial Services\t2010\t"$12     329 371 "\t"916            455 Dollars"\t11412916\t20%                                                NaN
# 3\tCanecorporation\tHealth\t2012\t"$10           597 009 "\t"7              591                                                  189 Dollars"\t3005820\t7%
# 4\tMattouch\tIT Services\t2013\t"$14             26  934 "\t\t6597557\t26%  NaN                                                                        NaN
# 5\tTechdrill\t\t2009\t"$10                       573 990 "\t\t3138627\t8%   NaN                                                                        NaN
# ...

# %%
df1.interpolate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-02691f4f5ea8> in <module>
# ----> 1 df1.interpolate()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7187
#    7188         if obj.ndim == 2 and np.all(obj.dtypes == np.dtype(object)):
# -> 7189             raise TypeError(
#    7190                 "Cannot interpolate with all object-dtype columns "
#    7191                 "in the DataFrame. Try setting at least one "
#
# TypeError: Cannot interpolate with all object-dtype columns in the DataFrame. Try setting at least one column to a numeric dtype.

# %%
df=pd.read_csv('F:\\Sachin\\IT Study\\Python\\Pandas\\student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df.loc[9]
# Out:
# Student ID                1010
# Class                       12
# Study hrs                    6
# Sleeping hrs                 9
# Social Media usage hrs       1
# Mobile Games hrs             0
# Percantege                  85
# Name: 9, dtype: int64

# %%
df.loc[[0,9]]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 9                 0          85

# %%
df.loc[[0,5,9]]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 5        1006     11         10             7                       0
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 5                 0          96
# 9                 0          85

# %%
df.loc[0:9,'Student ID']
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# 4    1005
# 5    1006
# 6    1007
# 7    1008
# 8    1009
# 9    1010
# Name: Student ID, dtype: int64

# %%
df.loc[0:2,'Percantege']
# Out:
# 0    50
# 1    80
# 2    60
# Name: Percantege, dtype: int64

# %%
df.loc[[False, False, True]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-11f2f3661fcc> in <module>
# ----> 1 df.loc[[False, False, True]]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1102             return self._get_slice_axis(key, axis=axis)
#    1103         elif com.is_bool_indexer(key):
# -> 1104             return self._getbool_axis(key, axis=axis)
#    1105         elif is_list_like_indexer(key):
#    1106
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
# ...

# %%
df.loc[df['Percantege'] < 70]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 8        1009     12          2             8                       2
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 2                 4          60
# 3                 5          45
# 8                 4          60

# %%
df.iloc[0]
# Out:
# Student ID                1001
# Class                       10
# Study hrs                    2
# Sleeping hrs                 9
# Social Media usage hrs       3
# Mobile Games hrs             5
# Percantege                  50
# Name: 0, dtype: int64

# %%
df.loc[0]
# Out:
# Student ID                1001
# Class                       10
# Study hrs                    2
# Sleeping hrs                 9
# Social Media usage hrs       3
# Mobile Games hrs             5
# Percantege                  50
# Name: 0, dtype: int64

# %%
df.iloc[[0]]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
#
#    Mobile Games hrs  Percantege
# 0                 5          50

# %%
df.iloc[[9]]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 9                 0          85

# %%
df.iloc[[0,9]]
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 9                 0          85

# %%
df.iloc[True,False,False]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-41-c1945a8f42c9> in <module>
# ----> 1 df.iloc[True,False,False]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1448     def _getitem_tuple(self, tup: Tuple):
#    1449
# -> 1450         self._has_valid_tuple(tup)
#    1451         with suppress(IndexingError):
#    1452             return self._getitem_lowerdim(tup)
#
# ...

# %%
df=pd.read_csv('F:\\Sachin\\IT Study\\Python\\Pandas\\student_result1.csv')
df
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 1        1002       B     10          6                       2          80
# 2        1003       A     10          3                       2          60
# 3        1004       C     11          0                       1          45
# 4        1005       C     12          5                       2          75

# %%
gr1= df.groupby(by='Section')
gr1

# %%
gr1.groups
# Out:
# {'A': [0, 2], 'B': [1], 'C': [3, 4]}

# %%
df.groupby(['Section','Class']).groups
# Out:
# {('A', 10): [0, 2], ('B', 10): [1], ('C', 11): [3], ('C', 12): [4]}

# %%
for Section, df_1 in gr1:
    print(Section)
    print(df_1)
# Out:
# A
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 2        1003       A     10          3                       2          60
# B
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 1        1002       B     10          6                       2          80
# C
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 3        1004       C     11          0                       1          45
# 4        1005       C     12          5                       2          75

# %%
gr1.sum()
# Out:
#          Student ID  Class  Study hrs  Social Media usage hrs  Percentage
# Section
# A              2004     20          5                       5         110
# B              1002     10          6                       2          80
# C              2009     23          5                       3         120

# %%
df=pd.read_csv('F:\\Sachin\\IT Study\\Python\\Pandas\\student_result1.csv')
df
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 1        1002       B     10          6                       2          80
# 2        1003       A     10          3                       2          60
# 3        1004       C     11          0                       1          45
# 4        1005       C     12          5                       2          75

# %%
gr1.mean()
# Out:
#          Student ID  Class  Study hrs  Social Media usage hrs  Percentage
# Section
# A            1002.0   10.0        2.5                     2.5        55.0
# B            1002.0   10.0        6.0                     2.0        80.0
# C            1004.5   11.5        2.5                     1.5        60.0

# %%
list(gr1)
# Out:
# [('A',
#      Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#   0        1001       A     10          2                       3          50
#   2        1003       A     10          3                       2          60),
#  ('B',
#      Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#   1        1002       B     10          6                       2          80),
#  ('C',
#      Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#   3        1004       C     11          0                       1          45
#   4        1005       C     12          5                       2          75)]

# %%
gr1.describe()
# Out:
#         Student ID                                                      \
#              count    mean       std     min      25%     50%      75%
# Section
# A              2.0  1002.0  1.414214  1001.0  1001.50  1002.0  1002.50
# B              1.0  1002.0       NaN  1002.0  1002.00  1002.0  1002.00
# C              2.0  1004.5  0.707107  1004.0  1004.25  1004.5  1004.75
#
#                 Class        ... Social Media usage hrs      Percentage        \
#             max count  mean  ...                    75%  max      count  mean
# Section                      ...
# A        1003.0   2.0  10.0  ...                   2.75  3.0        2.0  55.0
# B        1002.0   1.0  10.0  ...                   2.00  2.0        1.0  80.0
# C        1005.0   2.0  11.5  ...                   1.75  2.0        2.0  60.0
#
#
#                std   min   25%   50%   75%   max
# Section
# A         7.071068  50.0  52.5  55.0  57.5  60.0
# B              NaN  80.0  80.0  80.0  80.0  80.0
# ...

# %%
dict(list(gr1))
# Out:
# {'A':    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#  0        1001       A     10          2                       3          50
#  2        1003       A     10          3                       2          60,
#  'B':    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#  1        1002       B     10          6                       2          80,
#  'C':    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
#  3        1004       C     11          0                       1          45
#  4        1005       C     12          5                       2          75}

# %%
gr3= df.groupby('Class').get_group(10)
gr3
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 1        1002       B     10          6                       2          80
# 2        1003       A     10          3                       2          60

# %%
gr3 =df.groupby('Section').get_group('A')
gr3
# Out:
#    Student ID Section  Class  Study hrs  Social Media usage hrs  Percentage
# 0        1001       A     10          2                       3          50
# 2        1003       A     10          3                       2          60

# %%
gr1.agg(['sum','max','mean'])
# Out:
#         Student ID               Class           Study hrs           \
#                sum   max    mean   sum max  mean       sum max mean
# Section
# A             2004  1003  1002.0    20  10  10.0         5   3  2.5
# B             1002  1002  1002.0    10  10  10.0         6   6  6.0
# C             2009  1005  1004.5    23  12  11.5         5   5  2.5
#
#         Social Media usage hrs          Percentage
#                            sum max mean        sum max mean
# Section
# A                            5   3  2.5        110  60   55
# B                            2   2  2.0         80  80   80
# C                            3   2  1.5        120  75   60

# %%
df1= pd.DataFrame({'ID': [1,2,3,5], 'Class': [9,10,11,12]})
df1
# Out:
#    ID  Class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   5     12

# %%
df2= pd.DataFrame({'ID': [1,2,3,4], 'Name': ['A','B','C','D']})
df2
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   4    D

# %%
pd.merge(df1,df2,on='ID')
# Out:
#    ID  Class Name
# 0   1      9    A
# 1   2     10    B
# 2   3     11    C
# 3   4     12    D

# %%
pd.merge(df2,df1, on='ID')
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   4    D     12

# %%
pd.merge(df2,df1, on='ID')
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11

# %%
pd.merge(df2,df1, on='ID', how ='right')
# Out:
#    ID Name  Class
# 0   1    A      9
# 1   2    B     10
# 2   3    C     11
# 3   5  NaN     12

# %%
pd.merge(df2,df1, on='ID', how ='outer')
# Out:
#    ID Name  Class
# 0   1    A    9.0
# 1   2    B   10.0
# 2   3    C   11.0
# 3   4    D    NaN
# 4   5  NaN   12.0

# %%
pd.merge(df2,df1, on='ID', how ='outer', indicator = True)
# Out:
#    ID Name  Class      _merge
# 0   1    A    9.0        both
# 1   2    B   10.0        both
# 2   3    C   11.0        both
# 3   4    D    NaN   left_only
# 4   5  NaN   12.0  right_only

# %% [markdown]
# df2

# %%
df1
# Out:
#    ID  Class
# 0   1      9
# 1   2     10
# 2   3     11
# 3   5     12

# %%
df2
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   4    D

# %%
df2= pd.DataFrame({'ID': [5,6,7,8], 'Name': ['A','B','C','D']})
df2
# Out:
#    ID Name
# 0   5    A
# 1   6    B
# 2   7    C
# 3   8    D

# %%
pd.merge( df1, df2, left_index =True, right_index =True)
# Out:
#    ID_x  Class  ID_y Name
# 0     1      9     5    A
# 1     2     10     6    B
# 2     3     11     7    C
# 3     5     12     8    D

# %%
pd.merge(df1,df2,on='ID')
# Out:
#    ID  Class Name
# 0   5     12    A

# %%
df3= pd.DataFrame({'ID': [1,2,3,4], 'Class': ['A','B','C','D']})
df3
# Out:
#    ID Class
# 0   1     A
# 1   2     B
# 2   3     C
# 3   4     D

# %%
pd.merge(df1,df3,on ='ID')
# Out:
#    ID  Class_x Class_y
# 0   1        9       A
# 1   2       10       B
# 2   3       11       C

# %%
import pandas as pd

# %%
sr1= pd.Series([0,1,2])
sr1
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
sr2 = pd.Series([3,4,5,6,7])
sr2
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
pd.concat([sr1,sr2])
# Out:
# 0    0
# 1    1
# 2    2
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
df1 = pd.DataFrame({'ID':[1,2,3,4],'Name':['A','B','C','D'], 'Class':[5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2 = pd.DataFrame({'ID':[5,6,7,8],'Name':['E','F','G','H'], 'Class':[9,10,11,12]})
df2
# Out:
#    ID Name  Class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df1,df2])
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df2,df1],axis =1)
# Out:
#    ID Name  Class  ID Name  Class
# 0   5    E      9   1    A      5
# 1   6    F     10   2    B      6
# 2   7    G     11   3    C      7
# 3   8    H     12   4    D      8

# %%
pd.concat([df2,df1], ignore_index = True)
# Out:
#    ID Name  Class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12
# 4   1    A      5
# 5   2    B      6
# 6   3    C      7
# 7   4    D      8

# %%
df1 = pd.DataFrame({'ID':[3,4],'Name':['C','D'], 'Class':[7,8]})
df1
# Out:
#    ID Name  Class
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1,df2])
# Out:
#    ID Name  Class
# 0   3    C      7
# 1   4    D      8
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df1,df2], axis =1)
# Out:
#     ID Name  Class  ID Name  Class
# 0  3.0    C    7.0   5    E      9
# 1  4.0    D    8.0   6    F     10
# 2  NaN  NaN    NaN   7    G     11
# 3  NaN  NaN    NaN   8    H     12

# %%
pd.concat([df1,df2], axis =1, join ='inner')
# Out:
#    ID Name  Class  ID Name  Class
# 0   3    C      7   5    E      9
# 1   4    D      8   6    F     10

# %%
pd.concat([df1,df2], axis =1, join_axes = [df1.index])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-6eecce212c0e> in <module>
# ----> 1 pd.concat([df1,df2], axis =1, join_axes =[df1.index])
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'

# %%
pd.concat([df1,df2], join_axes = [df2.index])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-9685d6fb4917> in <module>
# ----> 1 pd.concat([df1,df2], join_axes = [df2.index])
#
# TypeError: concat() got an unexpected keyword argument 'join_axes'

# %%
pd.concat([df1,df2], axis =1, 'join_axes' = [df1.index] )
# Out:
#   File "<ipython-input-32-6c7430e18ec7>", line 1
#     pd.concat([df1,df2], axis =1, 'join_axes' = [df1.index] )
#                                   ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
pd.concat([df1,df2], axis =0, keys = ['first df ','second df'])
# Out:
#              ID Name  Class
# first df  0   3    C      7
#           1   4    D      8
# second df 0   5    E      9
#           1   6    F     10
#           2   7    G     11
#           3   8    H     12

# %%
pd.concat([df1,df2], axis =1, keys = ['first df ','second df'])
# Out:
#   first df             second df
#          ID Name Class        ID Name Class
# 0       3.0    C   7.0         5    E     9
# 1       4.0    D   8.0         6    F    10
# 2       NaN  NaN   NaN         7    G    11
# 3       NaN  NaN   NaN         8    H    12

# %%
df1 = pd.DataFrame({'ID':[1,2,3,4],'Name':['A','B','C','D'], 'Class':[5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2 = pd.DataFrame({'Marks' : [40, 70,56,95]})
df2
# Out:
#    Marks
# 0     40
# 1     70
# 2     56
# 3     95

# %%
pd.concat([df1,df2])
# Out:
#     ID Name  Class  Marks
# 0  1.0    A    5.0    NaN
# 1  2.0    B    6.0    NaN
# 2  3.0    C    7.0    NaN
# 3  4.0    D    8.0    NaN
# 0  NaN  NaN    NaN   40.0
# 1  NaN  NaN    NaN   70.0
# 2  NaN  NaN    NaN   56.0
# 3  NaN  NaN    NaN   95.0

# %%
df1 = pd.DataFrame({'A': [1,2,3], 'B': [10,20,30]},index =['a','b','c'])
df2 = pd.DataFrame({'A': [4,5,6], 'D': [40,50,60]},index=['a','b','c'])
display(df1,df2)
# Out:
#    A   B
# a  1  10
# b  2  20
# c  3  30
#    A   D
# a  4  40
# b  5  50
# c  6  60

# %%
df1.join(df2)
# Out:
#    A   B  C   D
# 0  1  10  4  40
# 1  2  20  5  50
# 2  3  30  6  60

# %%
df1.join(df2, lsuffix = "_l")
# Out:
#    A_l   B  A   D
# a    1  10  4  40
# b    2  20  5  50
# c    3  30  6  60

# %%
df1.join(df2, rsuffix = "_l")
# Out:
#    A   B  A_l   D
# a  1  10    4  40
# b  2  20    5  50
# c  3  30    6  60

# %%
import pandas as pd

# %%
df1 =pd.read_csv('F:\\Sachin\\IT Study\\Python\\Pandas\\student_results.csv')
df1
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df1.pivot_table(index='Class')
# Out:
#        Mobile Games hrs  Percantege  Sleeping hrs  Social Media usage hrs  \
# Class
# 10             3.000000   63.333333      8.333333                2.333333
# 11             1.666667   72.000000      8.000000                1.000000
# 12             1.000000   78.750000      7.250000                1.250000
#
#        Student ID  Study hrs
# Class
# 10         1002.0   3.666667
# 11         1005.0   4.666667
# 12         1008.5   5.500000

# %%
df1.pivot_table(index='Class', columns = "Study hrs")
# Out:
#           Mobile Games hrs                          Percantege              \
# Study hrs               0    2    3    4    6    10         0     2     3
# Class
# 10                     NaN  5.0  4.0  NaN  0.0  NaN        NaN  50.0  60.0
# 11                     5.0  NaN  NaN  0.0  NaN  0.0       45.0   NaN   NaN
# 12                     NaN  4.0  NaN  0.0  0.0  0.0        NaN  60.0   NaN
#
#                  ... Social Media usage hrs                Student ID          \
# Study hrs    4   ...                     3    4    6    10         0       2
# Class            ...
# 10          NaN  ...                    2.0  NaN  2.0  NaN        NaN  1001.0
# 11         75.0  ...                    NaN  2.0  NaN  0.0     1004.0     NaN
# 12         80.0  ...                    NaN  0.0  1.0  2.0        NaN  1009.0
#
#
# Study hrs      3       4       6       10
# Class
# 10         1003.0     NaN  1002.0     NaN
# 11            NaN  1005.0     NaN  1006.0
# ...

# %%
df1.pivot_table(index='Student ID', columns = "Study hrs", aggfunc ='Class'
# Out:
#   File "<ipython-input-13-d8cbf1586379>", line 1
#     df1.pivot_table(index='Student ID', columns = "Study hrs", aggfunc ='Class'
#                                                                                ^
# SyntaxError: unexpected EOF while parsing
